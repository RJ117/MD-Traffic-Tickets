# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
df = pd.read_csv('C:/Users/RJ/OneDrive/Dataset//traffic-violations-in-maryland-county-20122018/Traffic_Violations.csv')
# Out:
# C:\Users\RJ\Anaconda3.1\lib\site-packages\IPython\core\interactiveshell.py:2698: DtypeWarning: Columns (26) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head()
# Out:
#   Date Of Stop Time Of Stop Agency  \
# 0   09/24/2013     17:11:00    MCP
# 1   08/29/2017     10:19:00    MCP
# 2   12/01/2014     12:52:00    MCP
# 3   08/29/2017     09:22:00    MCP
# 4   08/28/2017     23:41:00    MCP
#
#                                          SubAgency  \
# 0                      3rd district, Silver Spring
# 1                           2nd district, Bethesda
# 2  6th district, Gaithersburg / Montgomery Village
# 3                      3rd district, Silver Spring
# 4  6th district, Gaithersburg / Montgomery Village
#
#                                          Description  \
# 0  DRIVING VEHICLE ON HIGHWAY WITH SUSPENDED REGI...
# 1  DRIVER FAILURE TO OBEY PROPERLY PLACED TRAFFIC...
# 2                 FAILURE STOP AND YIELD AT THRU HWY
# 3               FAILURE YIELD RIGHT OF WAY ON U TURN
# 4  FAILURE OF DR. TO MAKE LANE CHANGE TO AVAIL. L...
#
#                                  Location   Latitude  Longitude Accident  \
# ...

# %%
df.columns
# Out:
# Index(['Date Of Stop', 'Time Of Stop', 'Agency', 'SubAgency', 'Description',
#        'Location', 'Latitude', 'Longitude', 'Accident', 'Belts',
#        'Personal Injury', 'Property Damage', 'Fatal', 'Commercial License',
#        'HAZMAT', 'Commercial Vehicle', 'Alcohol', 'Work Zone', 'State',
#        'VehicleType', 'Year', 'Make', 'Model', 'Color', 'Violation Type',
#        'Charge', 'Article', 'Contributed To Accident', 'Race', 'Gender',
#        'Driver City', 'Driver State', 'DL State', 'Arrest Type',
#        'Geolocation'],
#       dtype='object')

# %%
df.Race.unique
# Out:
# <bound method Series.unique of 0             BLACK
# 1             WHITE
# 2             BLACK
# 3             BLACK
# 4             WHITE
# 5             WHITE
# 6          HISPANIC
# 7          HISPANIC
# 8             WHITE
# 9             WHITE
# 10            WHITE
# 11         HISPANIC
# 12            WHITE
# 13            WHITE
# 14            ASIAN
# 15            BLACK
# 16            BLACK
# 17            BLACK
# 18            WHITE
# 19            BLACK
# 20            WHITE
# 21         HISPANIC
# 22            WHITE
# 23            BLACK
# 24         HISPANIC
# 25            OTHER
# 26            BLACK
# 27            WHITE
# 28         HISPANIC
# 29         HISPANIC
#              ...
# 1292369       WHITE
# 1292370       WHITE
# 1292371       WHITE
# 1292372       OTHER
# 1292373    HISPANIC
# 1292374       BLACK
# 1292375       BLACK
# 1292376       WHITE
# 1292377       BLACK
# 1292378       WHITE
# 1292379    HISPANIC
# 1292380       ASIAN
# 1292381       BLACK
# ...

# %%
df['Race'].describe()
# Out:
# count     1292399
# unique          6
# top         WHITE
# freq       465808
# Name: Race, dtype: object

# %%
sns.countplot('Race', data=df)

# %%
df['Arrest Type'].describe()
# Out:
# count               1292399
# unique                   19
# top       A - Marked Patrol
# freq                1062884
# Name: Arrest Type, dtype: object

# %%
sns.countplot('Arrest Type', data=df)

# %%
df['Gender'].describe()
# Out:
# count     1292399
# unique          3
# top             M
# freq       865862
# Name: Gender, dtype: object

# %%
sns.countplot('Gender', data=df)

# %%
df['Time Of Stop'].describe()
# Out:
# count      1292399
# unique        1440
# top       22:53:00
# freq          1921
# Name: Time Of Stop, dtype: object

# %%
df['Location'].describe()
# Out:
# count             1292397
# unique             186999
# top       IS 370 @ IS 270
# freq                 1981
# Name: Location, dtype: object

# %%
sns.countplot('Location', data=df)

# %%
df['SubAgency'].describe()
# Out:
# count                   1292389
# unique                        7
# top       4th district, Wheaton
# freq                     322815
# Name: SubAgency, dtype: object

# %%
sns.countplot('SubAgency', data=df)

# %%
df
# Out:
#         Date Of Stop Time Of Stop Agency  \
# 0         09/24/2013     17:11:00    MCP
# 1         08/29/2017     10:19:00    MCP
# 2         12/01/2014     12:52:00    MCP
# 3         08/29/2017     09:22:00    MCP
# 4         08/28/2017     23:41:00    MCP
# 5         08/27/2013     00:55:00    MCP
# 6         10/08/2013     13:23:00    MCP
# 7         04/24/2015     00:38:00    MCP
# 8         08/28/2017     23:41:00    MCP
# 9         08/28/2017     23:41:00    MCP
# 10        02/14/2014     20:10:00    MCP
# 11        03/19/2012     16:10:00    MCP
# 12        06/09/2012     21:19:00    MCP
# 13        12/20/2012     00:41:00    MCP
# 14        07/20/2012     23:12:00    MCP
# 15        09/11/2012     21:47:00    MCP
# 16        07/23/2013     23:15:00    MCP
# 17        10/28/2013     17:41:00    MCP
# 18        08/28/2017     23:41:00    MCP
# 19        12/17/2015     13:15:00    MCP
# 20        08/28/2017     23:41:00    MCP
# 21        05/12/2015     08:26:00    MCP
# ...

# %%
import plotly.plotly as py
import plotly.graph_objs as go

trace1 = go.Bar(
    x=['Race'],
    y=[50000, 60000, 70000, 80000, 90000, 100000, 110000, 120000, 130000, 140000, 150000, 160000, 170000, 180000, 190000, 200000],
    name='Tickets Base on Ethnicity',
    marker=dict(
        color='rgb(55, 83, 109)'
    )
)
trace2 = go.Bar(
    x=['Gender'],
    y=[[50000, 60000, 70000, 80000, 90000, 100000, 110000, 120000, 130000, 140000, 150000, 160000, 170000, 180000, 190000, 200000],
    name='Gender Breakdown',
    marker=dict(
        color='rgb(26, 118, 255)'
    )
)
data = [trace1, trace2]
layout = go.Layout(
    title='Gender and Ethnicity Breakdown',
    xaxis=dict(
        tickfont=dict(
            size=14,
            color='rgb(107, 107, 107)'
        )
    ),
    yaxis=dict(
        title='Maryland',
        titlefont=dict(
            size=16,
            color='rgb(107, 107, 107)'
        ),
        tickfont=dict(
            size=14,
            color='rgb(107, 107, 107)'
        )
    ),
    legend=dict(
        x=0,
        y=1.0,
        bgcolor='rgba(255, 255, 255, 0)',
        bordercolor='rgba(255, 255, 255, 0)'
    ),
    barmode='group',
    bargap=0.15,
    bargroupgap=0.1
)

fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename='style-bar')
# Out:
#   File "<ipython-input-22-1b75475761e1>", line 15
#     name='Gender Breakdown',
#         ^
# SyntaxError: invalid syntax
